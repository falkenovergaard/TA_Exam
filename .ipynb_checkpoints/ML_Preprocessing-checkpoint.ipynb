# %% [markdown]
# Load in our labeled data

# %%
import pandas as pd
from dateutil import parser

dataset = 'data/output/vader/vader_bitcoin.xlsx'
output_dataset_name = 'ML_Data/BTC_vader.csv'
price_data = 'data/price/BTC.xlsx'
dates = 'data/dates.csv'

df = pd.read_excel(dataset)
df.columns = ['date', 'comment', 'label', 'compound_score']
df['date'] = pd.to_datetime(df['date'], dayfirst=True)

# %%
del df['comment']
del df['compound_score']

# %%
df.head()
# Out:
#         date  label
# 0 2019-05-04      0
# 1 2019-05-04      1
# 2 2019-05-04      0
# 3 2019-05-04      0
# 4 2019-05-04      1

# %% [markdown]
# Loop through all comments and create a new DataFrame that hosts the number of positives and negatives for each day.

# %%
rows = []
prices = []
grouped = df.groupby('date')
for date, group in grouped:
    positives = len(group[group['label'] == 1])
    negatives = len(group[group['label'] == 0])
        
    new_row = {
        'date': date,
        'positives': positives,
        'negatives': negatives,
        'ratio': positives / (positives + negatives)
    }
    
    rows.append(new_row)

# %%
new_df = pd.DataFrame(rows)

# %%
new_df.tail()
# Out:
#           date  negatives  positives     ratio
# 457 2019-04-30         18          8  0.307692
# 458 2019-05-01         18         11  0.379310
# 459 2019-05-02         39         21  0.350000
# 460 2019-05-03         43         20  0.317460
# 461 2019-05-04         21         11  0.343750

# %% [markdown]
# # Join with dates, so we make sure we have all dates

# %%
df_dates = pd.read_csv(dates)
df_dates['date'] = pd.to_datetime(df_dates['date'])
df_dates.tail(10)
# Out:
#           date
# 478 2018-01-10
# 479 2018-01-09
# 480 2018-01-08
# 481 2018-01-07
# 482 2018-01-06
# 483 2018-01-05
# 484 2018-01-04
# 485 2018-01-03
# 486 2018-01-02
# 487 2018-01-01

# %%
new_df = pd.merge(df_dates, new_df, on='date', how='outer')

# %%
new_df.fillna(0, inplace=True)

# %%
new_df.head(10)
# Out:
#         date  negatives  positives     ratio
# 0 2019-05-03       43.0       20.0  0.317460
# 1 2019-05-02       39.0       21.0  0.350000
# 2 2019-05-01       18.0       11.0  0.379310
# 3 2019-04-30       18.0        8.0  0.307692
# 4 2019-04-29       15.0        7.0  0.318182
# 5 2019-04-28       30.0        9.0  0.230769
# 6 2019-04-27       25.0       17.0  0.404762
# 7 2019-04-26       32.0       23.0  0.418182
# 8 2019-04-25       29.0       27.0  0.482143
# 9 2019-04-24       24.0       23.0  0.489362

# %% [markdown]
# Loop through new DataFrame and add 2 lags to each day. First we reverse order of DataFrame.

# %%
new_df = new_df.iloc[::-1]

lags = range(1, 8)

# %%
new_df = new_df.assign(**{
    '{} (t-{})'.format(col, t): new_df[col].shift(t)
    for t in lags
    for col in new_df
})

# %%
del new_df['date (t-1)']
del new_df['date (t-2)']
del new_df['date (t-3)']
del new_df['date (t-4)']
del new_df['date (t-5)']
del new_df['date (t-6)']
del new_df['date (t-7)']

# %%
new_df.fillna(0, inplace=True)
new_df.head(10)
# Out:
#           date  negatives  positives     ratio  negatives (t-1)  \
# 488 2019-05-04       21.0       11.0  0.343750              0.0
# 487 2018-01-01       69.0       38.0  0.355140             21.0
# 486 2018-01-02       75.0       37.0  0.330357             69.0
# 485 2018-01-03       24.0       25.0  0.510204             75.0
# 484 2018-01-04       25.0       14.0  0.358974             24.0
# 483 2018-01-05       52.0       36.0  0.409091             25.0
# 482 2018-01-06       44.0       19.0  0.301587             52.0
# 481 2018-01-07       15.0       17.0  0.531250             44.0
# 480 2018-01-08       73.0       45.0  0.381356             15.0
# 479 2018-01-09       17.0       14.0  0.451613             73.0
#
#      positives (t-1)  ratio (t-1)  negatives (t-2)  positives (t-2)  \
# 488              0.0     0.000000              0.0              0.0
# 487             11.0     0.343750              0.0              0.0
# 486             38.0     0.355140             21.0             11.0
# 485             37.0     0.330357             69.0             38.0
# 484             25.0     0.510204             75.0             37.0
# 483             14.0     0.358974             24.0             25.0
# 482             36.0     0.409091             25.0             14.0
# 481             19.0     0.301587             52.0             36.0
# 480             17.0     0.531250             44.0             19.0
# 479             45.0     0.381356             15.0             17.0
#
#      ratio (t-2)     ...       ratio (t-4)  negatives (t-5)  positives (t-5)  \
# 488     0.000000     ...          0.000000              0.0              0.0
# 487     0.000000     ...          0.000000              0.0              0.0
# 486     0.343750     ...          0.000000              0.0              0.0
# 485     0.355140     ...          0.000000              0.0              0.0
# 484     0.330357     ...          0.343750              0.0              0.0
# 483     0.510204     ...          0.355140             21.0             11.0
# 482     0.358974     ...          0.330357             69.0             38.0
# 481     0.409091     ...          0.510204             75.0             37.0
# 480     0.301587     ...          0.358974             24.0             25.0
# 479     0.531250     ...          0.409091             25.0             14.0
#
#      ratio (t-5)  negatives (t-6)  positives (t-6)  ratio (t-6)  \
# 488     0.000000              0.0              0.0     0.000000
# 487     0.000000              0.0              0.0     0.000000
# 486     0.000000              0.0              0.0     0.000000
# 485     0.000000              0.0              0.0     0.000000
# 484     0.000000              0.0              0.0     0.000000
# 483     0.343750              0.0              0.0     0.000000
# 482     0.355140             21.0             11.0     0.343750
# 481     0.330357             69.0             38.0     0.355140
# 480     0.510204             75.0             37.0     0.330357
# 479     0.358974             24.0             25.0     0.510204
#
#      negatives (t-7)  positives (t-7)  ratio (t-7)
# 488              0.0              0.0     0.000000
# 487              0.0              0.0     0.000000
# 486              0.0              0.0     0.000000
# 485              0.0              0.0     0.000000
# 484              0.0              0.0     0.000000
# 483              0.0              0.0     0.000000
# 482              0.0              0.0     0.000000
# 481             21.0             11.0     0.343750
# 480             69.0             38.0     0.355140
# 479             75.0             37.0     0.330357
#
# [10 rows x 25 columns]

# %%
new_df = new_df.sort_values(['date'],ascending=[False])

# %%
new_df.head(10)
# Out:
#           date  negatives  positives     ratio  negatives (t-1)  \
# 488 2019-05-04       21.0       11.0  0.343750              0.0
# 0   2019-05-03       43.0       20.0  0.317460             39.0
# 1   2019-05-02       39.0       21.0  0.350000             18.0
# 2   2019-05-01       18.0       11.0  0.379310             18.0
# 3   2019-04-30       18.0        8.0  0.307692             15.0
# 4   2019-04-29       15.0        7.0  0.318182             30.0
# 5   2019-04-28       30.0        9.0  0.230769             25.0
# 6   2019-04-27       25.0       17.0  0.404762             32.0
# 7   2019-04-26       32.0       23.0  0.418182             29.0
# 8   2019-04-25       29.0       27.0  0.482143             24.0
#
#      positives (t-1)  ratio (t-1)  negatives (t-2)  positives (t-2)  \
# 488              0.0     0.000000              0.0              0.0
# 0               21.0     0.350000             18.0             11.0
# 1               11.0     0.379310             18.0              8.0
# 2                8.0     0.307692             15.0              7.0
# 3                7.0     0.318182             30.0              9.0
# 4                9.0     0.230769             25.0             17.0
# 5               17.0     0.404762             32.0             23.0
# 6               23.0     0.418182             29.0             27.0
# 7               27.0     0.482143             24.0             23.0
# 8               23.0     0.489362             23.0             22.0
#
#      ratio (t-2)     ...       ratio (t-4)  negatives (t-5)  positives (t-5)  \
# 488     0.000000     ...          0.000000              0.0              0.0
# 0       0.379310     ...          0.318182             30.0              9.0
# 1       0.307692     ...          0.230769             25.0             17.0
# 2       0.318182     ...          0.404762             32.0             23.0
# 3       0.230769     ...          0.418182             29.0             27.0
# 4       0.404762     ...          0.482143             24.0             23.0
# 5       0.418182     ...          0.489362             23.0             22.0
# 6       0.482143     ...          0.488889             25.0             17.0
# 7       0.489362     ...          0.404762             16.0             10.0
# 8       0.488889     ...          0.384615             19.0              7.0
#
#      ratio (t-5)  negatives (t-6)  positives (t-6)  ratio (t-6)  \
# 488     0.000000              0.0              0.0     0.000000
# 0       0.230769             25.0             17.0     0.404762
# 1       0.404762             32.0             23.0     0.418182
# 2       0.418182             29.0             27.0     0.482143
# 3       0.482143             24.0             23.0     0.489362
# 4       0.489362             23.0             22.0     0.488889
# 5       0.488889             25.0             17.0     0.404762
# 6       0.404762             16.0             10.0     0.384615
# 7       0.384615             19.0              7.0     0.269231
# 8       0.269231              9.0             12.0     0.571429
#
#      negatives (t-7)  positives (t-7)  ratio (t-7)
# 488              0.0              0.0     0.000000
# 0               32.0             23.0     0.418182
# 1               29.0             27.0     0.482143
# 2               24.0             23.0     0.489362
# 3               23.0             22.0     0.488889
# 4               25.0             17.0     0.404762
# 5               16.0             10.0     0.384615
# 6               19.0              7.0     0.269231
# 7                9.0             12.0     0.571429
# 8               27.0             11.0     0.289474
#
# [10 rows x 25 columns]

# %% [markdown]
# # Merge with price data

# %%
df_price = pd.read_excel(price_data, skiprows=[0])
df_price['date'] = pd.to_datetime(df_price['Date'])

new_df = pd.merge(new_df, df_price, how='inner', on='date')

# %%
new_df.head(10)
# Out:
#         date  negatives  positives     ratio  negatives (t-1)  \
# 0 2019-05-04       21.0       11.0  0.343750              0.0
# 1 2019-05-03       43.0       20.0  0.317460             39.0
# 2 2019-05-02       39.0       21.0  0.350000             18.0
# 3 2019-05-01       18.0       11.0  0.379310             18.0
# 4 2019-04-30       18.0        8.0  0.307692             15.0
# 5 2019-04-29       15.0        7.0  0.318182             30.0
# 6 2019-04-28       30.0        9.0  0.230769             25.0
# 7 2019-04-27       25.0       17.0  0.404762             32.0
# 8 2019-04-26       32.0       23.0  0.418182             29.0
# 9 2019-04-25       29.0       27.0  0.482143             24.0
#
#    positives (t-1)  ratio (t-1)  negatives (t-2)  positives (t-2)  \
# 0              0.0     0.000000              0.0              0.0
# 1             21.0     0.350000             18.0             11.0
# 2             11.0     0.379310             18.0              8.0
# 3              8.0     0.307692             15.0              7.0
# 4              7.0     0.318182             30.0              9.0
# 5              9.0     0.230769             25.0             17.0
# 6             17.0     0.404762             32.0             23.0
# 7             23.0     0.418182             29.0             27.0
# 8             27.0     0.482143             24.0             23.0
# 9             23.0     0.489362             23.0             22.0
#
#    ratio (t-2)     ...       ratio (t-6)  negatives (t-7)  positives (t-7)  \
# 0     0.000000     ...          0.000000              0.0              0.0
# 1     0.379310     ...          0.404762             32.0             23.0
# 2     0.307692     ...          0.418182             29.0             27.0
# 3     0.318182     ...          0.482143             24.0             23.0
# 4     0.230769     ...          0.489362             23.0             22.0
# 5     0.404762     ...          0.488889             25.0             17.0
# 6     0.418182     ...          0.404762             16.0             10.0
# 7     0.482143     ...          0.384615             19.0              7.0
# 8     0.489362     ...          0.269231              9.0             12.0
# 9     0.488889     ...          0.571429             27.0             11.0
#
#    ratio (t-7)     Date         High          Low  Upper Bound  Lower Bound  \
# 0     0.000000   5/4/19  5849.500000  5709.740234  7311.875000  4282.305175
# 1     0.418182   5/3/19  5901.359863  5596.149902  7376.699829  4197.112426
# 2     0.482143   5/2/19  5891.899902  5484.779785  7364.874878  4113.584839
# 3     0.489362   5/1/19  5531.149902  5387.290039  6913.937378  4040.467529
# 4     0.488889  4/30/19  5417.169922  5346.700195  6771.462403  4010.025146
# 5     0.404762  4/29/19  5372.229980  5224.640137  6715.287475  3918.480103
# 6     0.384615  4/28/19  5299.509766  5162.810059  6624.387207  3872.107544
# 7     0.269231  4/27/19  5313.700195  5218.419922  6642.125244  3913.814941
# 8     0.571429  4/26/19  5282.970215  5192.450195  6603.712769  3894.337646
# 9     0.289474  4/25/19  5361.939941  5104.180176  6702.424926  3828.135132
#
#          Close
# 0  5794.140137
# 1  5840.080078
# 2  5753.379883
# 3  5500.720215
# 4  5389.540039
# 5  5350.640137
# 6  5237.959961
# 7  5272.450195
# 8  5229.479980
# 9  5234.089844
#
# [10 rows x 31 columns]

# %%
new_df['label'] = new_df['Close'] > new_df['Close'].shift(-1)
new_df['label'] = new_df['label'].astype(int)

# %%
new_df.head(25)
# Out:
#          date  negatives  positives     ratio  negatives (t-1)  \
# 0  2019-05-04       21.0       11.0  0.343750              0.0
# 1  2019-05-03       43.0       20.0  0.317460             39.0
# 2  2019-05-02       39.0       21.0  0.350000             18.0
# 3  2019-05-01       18.0       11.0  0.379310             18.0
# 4  2019-04-30       18.0        8.0  0.307692             15.0
# 5  2019-04-29       15.0        7.0  0.318182             30.0
# 6  2019-04-28       30.0        9.0  0.230769             25.0
# 7  2019-04-27       25.0       17.0  0.404762             32.0
# 8  2019-04-26       32.0       23.0  0.418182             29.0
# 9  2019-04-25       29.0       27.0  0.482143             24.0
# 10 2019-04-24       24.0       23.0  0.489362             23.0
# 11 2019-04-23       23.0       22.0  0.488889             25.0
# 12 2019-04-22       25.0       17.0  0.404762             16.0
# 13 2019-04-21       16.0       10.0  0.384615             19.0
# 14 2019-04-20       19.0        7.0  0.269231              9.0
# 15 2019-04-19        9.0       12.0  0.571429             27.0
# 16 2019-04-18       27.0       11.0  0.289474             21.0
# 17 2019-04-17       21.0       15.0  0.416667             24.0
# 18 2019-04-16       24.0       13.0  0.351351             21.0
# 19 2019-04-15       21.0       13.0  0.382353             14.0
# 20 2019-04-14       14.0        6.0  0.300000              9.0
# 21 2019-04-13        9.0        6.0  0.400000             23.0
# 22 2019-04-12       23.0        8.0  0.258065             32.0
# 23 2019-04-11       32.0       32.0  0.500000             42.0
# 24 2019-04-10       42.0       25.0  0.373134             18.0
#
#     positives (t-1)  ratio (t-1)  negatives (t-2)  positives (t-2)  \
# 0               0.0     0.000000              0.0              0.0
# 1              21.0     0.350000             18.0             11.0
# 2              11.0     0.379310             18.0              8.0
# 3               8.0     0.307692             15.0              7.0
# 4               7.0     0.318182             30.0              9.0
# 5               9.0     0.230769             25.0             17.0
# 6              17.0     0.404762             32.0             23.0
# 7              23.0     0.418182             29.0             27.0
# 8              27.0     0.482143             24.0             23.0
# 9              23.0     0.489362             23.0             22.0
# 10             22.0     0.488889             25.0             17.0
# 11             17.0     0.404762             16.0             10.0
# 12             10.0     0.384615             19.0              7.0
# 13              7.0     0.269231              9.0             12.0
# 14             12.0     0.571429             27.0             11.0
# 15             11.0     0.289474             21.0             15.0
# 16             15.0     0.416667             24.0             13.0
# 17             13.0     0.351351             21.0             13.0
# 18             13.0     0.382353             14.0              6.0
# 19              6.0     0.300000              9.0              6.0
# 20              6.0     0.400000             23.0              8.0
# 21              8.0     0.258065             32.0             32.0
# 22             32.0     0.500000             42.0             25.0
# 23             25.0     0.373134             18.0              8.0
# 24              8.0     0.307692             20.0             12.0
#
#     ratio (t-2)  ...    negatives (t-7)  positives (t-7)  ratio (t-7)  \
# 0      0.000000  ...                0.0              0.0     0.000000
# 1      0.379310  ...               32.0             23.0     0.418182
# 2      0.307692  ...               29.0             27.0     0.482143
# 3      0.318182  ...               24.0             23.0     0.489362
# 4      0.230769  ...               23.0             22.0     0.488889
# 5      0.404762  ...               25.0             17.0     0.404762
# 6      0.418182  ...               16.0             10.0     0.384615
# 7      0.482143  ...               19.0              7.0     0.269231
# 8      0.489362  ...                9.0             12.0     0.571429
# 9      0.488889  ...               27.0             11.0     0.289474
# 10     0.404762  ...               21.0             15.0     0.416667
# 11     0.384615  ...               24.0             13.0     0.351351
# 12     0.269231  ...               21.0             13.0     0.382353
# 13     0.571429  ...               14.0              6.0     0.300000
# 14     0.289474  ...                9.0              6.0     0.400000
# 15     0.416667  ...               23.0              8.0     0.258065
# 16     0.351351  ...               32.0             32.0     0.500000
# 17     0.382353  ...               42.0             25.0     0.373134
# 18     0.300000  ...               18.0              8.0     0.307692
# 19     0.400000  ...               20.0             12.0     0.375000
# 20     0.258065  ...               36.0             22.0     0.379310
# 21     0.500000  ...               23.0             16.0     0.410256
# 22     0.373134  ...               16.0             12.0     0.428571
# 23     0.307692  ...               25.0             23.0     0.479167
# 24     0.375000  ...               53.0             34.0     0.390805
#
#        Date         High          Low  Upper Bound  Lower Bound        Close  \
# 0    5/4/19  5849.500000  5709.740234  7311.875000  4282.305175  5794.140137
# 1    5/3/19  5901.359863  5596.149902  7376.699829  4197.112426  5840.080078
# 2    5/2/19  5891.899902  5484.779785  7364.874878  4113.584839  5753.379883
# 3    5/1/19  5531.149902  5387.290039  6913.937378  4040.467529  5500.720215
# 4   4/30/19  5417.169922  5346.700195  6771.462403  4010.025146  5389.540039
# 5   4/29/19  5372.229980  5224.640137  6715.287475  3918.480103  5350.640137
# 6   4/28/19  5299.509766  5162.810059  6624.387207  3872.107544  5237.959961
# 7   4/27/19  5313.700195  5218.419922  6642.125244  3913.814941  5272.450195
# 8   4/26/19  5282.970215  5192.450195  6603.712769  3894.337646  5229.479980
# 9   4/25/19  5361.939941  5104.180176  6702.424926  3828.135132  5234.089844
# 10  4/24/19  5521.609863  5031.689941  6902.012329  3773.767456  5162.669922
# 11  4/23/19  5633.000000  5390.979980  7041.250000  4043.234985  5454.580078
# 12  4/22/19  5626.830078  5371.310059  7033.537597  4028.482544  5539.100098
# 13  4/21/19  5444.759766  5265.729980  6805.949707  3949.297485  5394.669922
# 14  4/20/19  5348.589844  5232.770020  6685.737305  3924.577515  5305.740234
# 15  4/19/19  5366.600098  5274.450195  6708.250122  3955.837646  5326.180176
# 16  4/18/19  5353.009766  5212.180176  6691.262207  3909.135132  5295.529785
# 17  4/17/19  5317.779785  5232.990234  6647.224731  3924.742676  5289.750000
# 18  4/16/19  5270.759766  5190.810059  6588.449707  3893.107544  5236.259766
# 19  4/15/19  5232.029785  5029.160156  6540.037231  3771.870117  5212.810059
# 20  4/14/19  5195.310059  4969.310059  6494.137574  3726.982544  5037.270020
# 21  4/13/19  5186.819824  5031.200195  6483.524780  3773.400146  5165.589844
# 22  4/12/19  5128.959961  5056.189941  6411.199951  3792.142456  5080.660156
# 23  4/11/19  5118.609863  4927.620117  6398.262329  3695.715088  5081.500000
# 24  4/10/19  5343.660156  4987.649902  6679.575195  3740.737426  5048.560059
#
#     label
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
# 5       1
# 6       0
# 7       1
# 8       0
# 9       1
# 10      0
# 11      0
# 12      1
# 13      1
# 14      0
# 15      1
# 16      1
# 17      1
# 18      1
# 19      1
# 20      0
# 21      1
# 22      0
# 23      1
# 24      0
#
# [25 rows x 32 columns]

# %%
new_df.tail(10)
# Out:
#           date  negatives  positives     ratio  negatives (t-1)  \
# 480 2018-01-10       36.0       29.0  0.446154             17.0
# 481 2018-01-09       17.0       14.0  0.451613             73.0
# 482 2018-01-08       73.0       45.0  0.381356             15.0
# 483 2018-01-07       15.0       17.0  0.531250             44.0
# 484 2018-01-06       44.0       19.0  0.301587             52.0
# 485 2018-01-05       52.0       36.0  0.409091             25.0
# 486 2018-01-04       25.0       14.0  0.358974             24.0
# 487 2018-01-03       24.0       25.0  0.510204             75.0
# 488 2018-01-02       75.0       37.0  0.330357             69.0
# 489 2018-01-01       69.0       38.0  0.355140             21.0
#
#      positives (t-1)  ratio (t-1)  negatives (t-2)  positives (t-2)  \
# 480             14.0     0.451613             73.0             45.0
# 481             45.0     0.381356             15.0             17.0
# 482             17.0     0.531250             44.0             19.0
# 483             19.0     0.301587             52.0             36.0
# 484             36.0     0.409091             25.0             14.0
# 485             14.0     0.358974             24.0             25.0
# 486             25.0     0.510204             75.0             37.0
# 487             37.0     0.330357             69.0             38.0
# 488             38.0     0.355140             21.0             11.0
# 489             11.0     0.343750              0.0              0.0
#
#      ratio (t-2)  ...    negatives (t-7)  positives (t-7)  ratio (t-7)  \
# 480     0.381356  ...               24.0             25.0     0.510204
# 481     0.531250  ...               75.0             37.0     0.330357
# 482     0.301587  ...               69.0             38.0     0.355140
# 483     0.409091  ...               21.0             11.0     0.343750
# 484     0.358974  ...                0.0              0.0     0.000000
# 485     0.510204  ...                0.0              0.0     0.000000
# 486     0.330357  ...                0.0              0.0     0.000000
# 487     0.355140  ...                0.0              0.0     0.000000
# 488     0.343750  ...                0.0              0.0     0.000000
# 489     0.000000  ...                0.0              0.0     0.000000
#
#         Date          High           Low   Upper Bound   Lower Bound  \
# 480  1/10/18  14919.490234  13450.540039  18649.362793  10087.905029
# 481   1/9/18  15390.280273  14221.549805  19237.850341  10666.162354
# 482   1/8/18  16302.919922  13902.309570  20378.649903  10426.732178
# 483   1/7/18  17184.810547  15791.129883  21481.013184  11843.347412
# 484   1/6/18  17252.849609  16286.570313  21566.062011  12214.927735
# 485   1/5/18  17126.949219  14832.360352  21408.686524  11124.270264
# 486   1/4/18  15408.660156  14244.669922  19260.825195  10683.502442
# 487   1/3/18  15435.009766  14579.709961  19293.762207  10934.782471
# 488   1/2/18  15306.129883  12934.160156  19132.662354   9700.620117
# 489   1/1/18  13921.530273  12877.669922  17401.912841   9658.252442
#
#             Close  label
# 480  14919.490234      1
# 481  14468.500000      0
# 482  14976.169922      0
# 483  16228.160156      0
# 484  17172.300781      1
# 485  16954.779297      1
# 486  15180.080078      1
# 487  15156.620117      1
# 488  14754.129883      1
# 489  13444.879883      0
#
# [10 rows x 32 columns]

# %%
new_df = new_df.drop(['High', 'Low', 'Upper bound', 'Lower Bound', 'Close', 'Date'], axis=1)

# %%
new_df.head(10)
# Out:
#         date  negatives  positives     ratio  negatives (t-1)  \
# 0 2019-05-04       21.0       11.0  0.343750              0.0
# 1 2019-05-03       43.0       20.0  0.317460             39.0
# 2 2019-05-02       39.0       21.0  0.350000             18.0
# 3 2019-05-01       18.0       11.0  0.379310             18.0
# 4 2019-04-30       18.0        8.0  0.307692             15.0
# 5 2019-04-29       15.0        7.0  0.318182             30.0
# 6 2019-04-28       30.0        9.0  0.230769             25.0
# 7 2019-04-27       25.0       17.0  0.404762             32.0
# 8 2019-04-26       32.0       23.0  0.418182             29.0
# 9 2019-04-25       29.0       27.0  0.482143             24.0
#
#    positives (t-1)  ratio (t-1)  negatives (t-2)  positives (t-2)  \
# 0              0.0     0.000000              0.0              0.0
# 1             21.0     0.350000             18.0             11.0
# 2             11.0     0.379310             18.0              8.0
# 3              8.0     0.307692             15.0              7.0
# 4              7.0     0.318182             30.0              9.0
# 5              9.0     0.230769             25.0             17.0
# 6             17.0     0.404762             32.0             23.0
# 7             23.0     0.418182             29.0             27.0
# 8             27.0     0.482143             24.0             23.0
# 9             23.0     0.489362             23.0             22.0
#
#    ratio (t-2)  ...    negatives (t-5)  positives (t-5)  ratio (t-5)  \
# 0     0.000000  ...                0.0              0.0     0.000000
# 1     0.379310  ...               30.0              9.0     0.230769
# 2     0.307692  ...               25.0             17.0     0.404762
# 3     0.318182  ...               32.0             23.0     0.418182
# 4     0.230769  ...               29.0             27.0     0.482143
# 5     0.404762  ...               24.0             23.0     0.489362
# 6     0.418182  ...               23.0             22.0     0.488889
# 7     0.482143  ...               25.0             17.0     0.404762
# 8     0.489362  ...               16.0             10.0     0.384615
# 9     0.488889  ...               19.0              7.0     0.269231
#
#    negatives (t-6)  positives (t-6)  ratio (t-6)  negatives (t-7)  \
# 0              0.0              0.0     0.000000              0.0
# 1             25.0             17.0     0.404762             32.0
# 2             32.0             23.0     0.418182             29.0
# 3             29.0             27.0     0.482143             24.0
# 4             24.0             23.0     0.489362             23.0
# 5             23.0             22.0     0.488889             25.0
# 6             25.0             17.0     0.404762             16.0
# 7             16.0             10.0     0.384615             19.0
# 8             19.0              7.0     0.269231              9.0
# 9              9.0             12.0     0.571429             27.0
#
#    positives (t-7)  ratio (t-7)  label
# 0              0.0     0.000000      0
# 1             23.0     0.418182      0
# 2             27.0     0.482143      1
# 3             23.0     0.489362      1
# 4             22.0     0.488889      1
# 5             17.0     0.404762      1
# 6             10.0     0.384615      1
# 7              7.0     0.269231      0
# 8             12.0     0.571429      1
# 9             11.0     0.289474      0
#
# [10 rows x 26 columns]

# %%
new_df.to_csv(output_dataset_name)
