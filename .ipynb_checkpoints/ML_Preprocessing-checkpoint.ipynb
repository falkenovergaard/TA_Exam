# %% [markdown]
# Load in our labeled data

# %%
import pandas as pd
from dateutil import parser

dataset = 'ML_Data/tes_classified_pos.xlsx'
output_dataset_name = 'ML_Data/TSLA_pos.csv'
price_data = 'data/price/TSLA.xlsx'
dates = 'data/dates.csv'

df = pd.read_excel(dataset)
df.columns = ['date', 'comment', 'label', 'compound_score']
df['date'] = pd.to_datetime(df['date'], dayfirst=True)

# %%
del df['comment']
del df['compound_score']

# %%
df.head()
# Out:
#         date  label
# 0 2019-05-03      1
# 1 2019-05-03      0
# 2 2019-05-03      0
# 3 2019-05-03      0
# 4 2019-05-03      1

# %% [markdown]
# Loop through all comments and create a new DataFrame that hosts the number of positives and negatives for each day.

# %%
rows = []
prices = []
grouped = df.groupby('date')
for date, group in grouped:
    positives = len(group[group['label'] == 1])
    negatives = len(group[group['label'] == 0])
        
    new_row = {
        'date': date,
        'positives': positives,
        'negatives': negatives,
        'ratio': positives / (positives + negatives)
    }
    
    rows.append(new_row)

# %%
new_df = pd.DataFrame(rows)

# %%
new_df.tail()
# Out:
#           date  negatives  positives     ratio
# 311 2019-04-29         22         11  0.333333
# 312 2019-04-30         15         12  0.444444
# 313 2019-05-01         32         15  0.319149
# 314 2019-05-02         26         23  0.469388
# 315 2019-05-03         19         20  0.512821

# %% [markdown]
# # Join with dates, so we make sure we have all dates

# %%
df_dates = pd.read_csv(dates)
df_dates['date'] = pd.to_datetime(df_dates['date'])
df_dates.tail(10)
# Out:
#           date
# 478 2018-01-10
# 479 2018-01-09
# 480 2018-01-08
# 481 2018-01-07
# 482 2018-01-06
# 483 2018-01-05
# 484 2018-01-04
# 485 2018-01-03
# 486 2018-01-02
# 487 2018-01-01

# %%
test = pd.merge(df_dates, new_df, on='date', how='outer')

# %%
test.head(10)
# Out:
#         date  negatives  positives     ratio
# 0 2018-01-02        2.0        0.0  0.000000
# 1 2018-01-03        4.0        1.0  0.200000
# 2 2018-01-04        6.0        2.0  0.250000
# 3 2018-01-05        4.0        2.0  0.333333
# 4 2018-01-08        3.0        2.0  0.400000
# 5 2018-01-09        1.0        1.0  0.500000
# 6 2018-01-10        0.0        1.0  1.000000
# 7 2018-01-11        3.0        0.0  0.000000
# 8 2018-01-17        1.0        0.0  0.000000
# 9 2018-01-22        1.0        0.0  0.000000

# %% [markdown]
# Loop through new DataFrame and add 2 lags to each day

# %%
lags = range(1, 8)

# %%
new_df = new_df.assign(**{
    '{} (t-{})'.format(col, t): new_df[col].shift(t)
    for t in lags
    for col in new_df
})

# %%
del new_df['date (t-1)']
del new_df['date (t-2)']
del new_df['date (t-3)']
del new_df['date (t-4)']
del new_df['date (t-5)']
del new_df['date (t-6)']
del new_df['date (t-7)']

# %%
new_df.head(10)
# Out:
#         date  negatives  positives     ratio  negatives (t-1)  \
# 0 2018-01-02          2          0  0.000000              NaN
# 1 2018-01-03          4          1  0.200000              2.0
# 2 2018-01-04          6          2  0.250000              4.0
# 3 2018-01-05          4          2  0.333333              6.0
# 4 2018-01-08          3          2  0.400000              4.0
# 5 2018-01-09          1          1  0.500000              3.0
# 6 2018-01-10          0          1  1.000000              1.0
# 7 2018-01-11          3          0  0.000000              0.0
# 8 2018-01-17          1          0  0.000000              3.0
# 9 2018-01-22          1          0  0.000000              1.0
#
#    positives (t-1)  ratio (t-1)  negatives (t-2)  positives (t-2)  \
# 0              NaN          NaN              NaN              NaN
# 1              0.0     0.000000              NaN              NaN
# 2              1.0     0.200000              2.0              0.0
# 3              2.0     0.250000              4.0              1.0
# 4              2.0     0.333333              6.0              2.0
# 5              2.0     0.400000              4.0              2.0
# 6              1.0     0.500000              3.0              2.0
# 7              1.0     1.000000              1.0              1.0
# 8              0.0     0.000000              0.0              1.0
# 9              0.0     0.000000              3.0              0.0
#
#    ratio (t-2)     ...       ratio (t-4)  negatives (t-5)  positives (t-5)  \
# 0          NaN     ...               NaN              NaN              NaN
# 1          NaN     ...               NaN              NaN              NaN
# 2     0.000000     ...               NaN              NaN              NaN
# 3     0.200000     ...               NaN              NaN              NaN
# 4     0.250000     ...          0.000000              NaN              NaN
# 5     0.333333     ...          0.200000              2.0              0.0
# 6     0.400000     ...          0.250000              4.0              1.0
# 7     0.500000     ...          0.333333              6.0              2.0
# 8     1.000000     ...          0.400000              4.0              2.0
# 9     0.000000     ...          0.500000              3.0              2.0
#
#    ratio (t-5)  negatives (t-6)  positives (t-6)  ratio (t-6)  \
# 0          NaN              NaN              NaN          NaN
# 1          NaN              NaN              NaN          NaN
# 2          NaN              NaN              NaN          NaN
# 3          NaN              NaN              NaN          NaN
# 4          NaN              NaN              NaN          NaN
# 5     0.000000              NaN              NaN          NaN
# 6     0.200000              2.0              0.0     0.000000
# 7     0.250000              4.0              1.0     0.200000
# 8     0.333333              6.0              2.0     0.250000
# 9     0.400000              4.0              2.0     0.333333
#
#    negatives (t-7)  positives (t-7)  ratio (t-7)
# 0              NaN              NaN          NaN
# 1              NaN              NaN          NaN
# 2              NaN              NaN          NaN
# 3              NaN              NaN          NaN
# 4              NaN              NaN          NaN
# 5              NaN              NaN          NaN
# 6              NaN              NaN          NaN
# 7              2.0              0.0         0.00
# 8              4.0              1.0         0.20
# 9              6.0              2.0         0.25
#
# [10 rows x 25 columns]

# %%
new_df.fillna(0, inplace=True)

# %%
new_df = new_df.sort_values(['date'],ascending=[False])

# %%
new_df.head(10)
# Out:
#           date  negatives  positives     ratio  negatives (t-1)  \
# 315 2019-05-03         19         20  0.512821             26.0
# 314 2019-05-02         26         23  0.469388             32.0
# 313 2019-05-01         32         15  0.319149             15.0
# 312 2019-04-30         15         12  0.444444             22.0
# 311 2019-04-29         22         11  0.333333             65.0
# 310 2019-04-26         65         37  0.362745             87.0
# 309 2019-04-25         87         46  0.345865             59.0
# 308 2019-04-24         59         42  0.415842             16.0
# 307 2019-04-23         16         16  0.500000             22.0
# 306 2019-04-22         22         13  0.371429              5.0
#
#      positives (t-1)  ratio (t-1)  negatives (t-2)  positives (t-2)  \
# 315             23.0     0.469388             32.0             15.0
# 314             15.0     0.319149             15.0             12.0
# 313             12.0     0.444444             22.0             11.0
# 312             11.0     0.333333             65.0             37.0
# 311             37.0     0.362745             87.0             46.0
# 310             46.0     0.345865             59.0             42.0
# 309             42.0     0.415842             16.0             16.0
# 308             16.0     0.500000             22.0             13.0
# 307             13.0     0.371429              5.0             10.0
# 306             10.0     0.666667              3.0              4.0
#
#      ratio (t-2)     ...       ratio (t-4)  negatives (t-5)  positives (t-5)  \
# 315     0.319149     ...          0.333333             65.0             37.0
# 314     0.444444     ...          0.362745             87.0             46.0
# 313     0.333333     ...          0.345865             59.0             42.0
# 312     0.362745     ...          0.415842             16.0             16.0
# 311     0.345865     ...          0.500000             22.0             13.0
# 310     0.415842     ...          0.371429              5.0             10.0
# 309     0.500000     ...          0.666667              3.0              4.0
# 308     0.371429     ...          0.571429             11.0              9.0
# 307     0.666667     ...          0.450000             17.0              6.0
# 306     0.571429     ...          0.260870             12.0              9.0
#
#      ratio (t-5)  negatives (t-6)  positives (t-6)  ratio (t-6)  \
# 315     0.362745             87.0             46.0     0.345865
# 314     0.345865             59.0             42.0     0.415842
# 313     0.415842             16.0             16.0     0.500000
# 312     0.500000             22.0             13.0     0.371429
# 311     0.371429              5.0             10.0     0.666667
# 310     0.666667              3.0              4.0     0.571429
# 309     0.571429             11.0              9.0     0.450000
# 308     0.450000             17.0              6.0     0.260870
# 307     0.260870             12.0              9.0     0.428571
# 306     0.428571             18.0             19.0     0.513514
#
#      negatives (t-7)  positives (t-7)  ratio (t-7)
# 315             59.0             42.0     0.415842
# 314             16.0             16.0     0.500000
# 313             22.0             13.0     0.371429
# 312              5.0             10.0     0.666667
# 311              3.0              4.0     0.571429
# 310             11.0              9.0     0.450000
# 309             17.0              6.0     0.260870
# 308             12.0              9.0     0.428571
# 307             18.0             19.0     0.513514
# 306              7.0              9.0     0.562500
#
# [10 rows x 25 columns]

# %%
# Out:
#         date
# 0 2019-05-03
# 1 2019-05-02
# 2 2019-05-01
# 3 2019-04-30
# 4 2019-04-29
# 5 2019-04-28
# 6 2019-04-27
# 7 2019-04-26
# 8 2019-04-25
# 9 2019-04-24

# %%
new_df = pd.merge(new_df, df_dates, on='date', how='outer')

# %%
new_df.head(10)
# Out:
#         date  negatives  positives     ratio  negatives (t-1)  \
# 0 2019-05-03       19.0       20.0  0.512821             26.0
# 1 2019-05-02       26.0       23.0  0.469388             32.0
# 2 2019-05-01       32.0       15.0  0.319149             15.0
# 3 2019-04-30       15.0       12.0  0.444444             22.0
# 4 2019-04-29       22.0       11.0  0.333333             65.0
# 5 2019-04-26       65.0       37.0  0.362745             87.0
# 6 2019-04-25       87.0       46.0  0.345865             59.0
# 7 2019-04-24       59.0       42.0  0.415842             16.0
# 8 2019-04-23       16.0       16.0  0.500000             22.0
# 9 2019-04-22       22.0       13.0  0.371429              5.0
#
#    positives (t-1)  ratio (t-1)  negatives (t-2)  positives (t-2)  \
# 0             23.0     0.469388             32.0             15.0
# 1             15.0     0.319149             15.0             12.0
# 2             12.0     0.444444             22.0             11.0
# 3             11.0     0.333333             65.0             37.0
# 4             37.0     0.362745             87.0             46.0
# 5             46.0     0.345865             59.0             42.0
# 6             42.0     0.415842             16.0             16.0
# 7             16.0     0.500000             22.0             13.0
# 8             13.0     0.371429              5.0             10.0
# 9             10.0     0.666667              3.0              4.0
#
#    ratio (t-2)     ...       ratio (t-4)  negatives (t-5)  positives (t-5)  \
# 0     0.319149     ...          0.333333             65.0             37.0
# 1     0.444444     ...          0.362745             87.0             46.0
# 2     0.333333     ...          0.345865             59.0             42.0
# 3     0.362745     ...          0.415842             16.0             16.0
# 4     0.345865     ...          0.500000             22.0             13.0
# 5     0.415842     ...          0.371429              5.0             10.0
# 6     0.500000     ...          0.666667              3.0              4.0
# 7     0.371429     ...          0.571429             11.0              9.0
# 8     0.666667     ...          0.450000             17.0              6.0
# 9     0.571429     ...          0.260870             12.0              9.0
#
#    ratio (t-5)  negatives (t-6)  positives (t-6)  ratio (t-6)  \
# 0     0.362745             87.0             46.0     0.345865
# 1     0.345865             59.0             42.0     0.415842
# 2     0.415842             16.0             16.0     0.500000
# 3     0.500000             22.0             13.0     0.371429
# 4     0.371429              5.0             10.0     0.666667
# 5     0.666667              3.0              4.0     0.571429
# 6     0.571429             11.0              9.0     0.450000
# 7     0.450000             17.0              6.0     0.260870
# 8     0.260870             12.0              9.0     0.428571
# 9     0.428571             18.0             19.0     0.513514
#
#    negatives (t-7)  positives (t-7)  ratio (t-7)
# 0             59.0             42.0     0.415842
# 1             16.0             16.0     0.500000
# 2             22.0             13.0     0.371429
# 3              5.0             10.0     0.666667
# 4              3.0              4.0     0.571429
# 5             11.0              9.0     0.450000
# 6             17.0              6.0     0.260870
# 7             12.0              9.0     0.428571
# 8             18.0             19.0     0.513514
# 9              7.0              9.0     0.562500
#
# [10 rows x 25 columns]

# %%
df_price = pd.read_excel(price_data, skiprows=[0])
df_price['date'] = pd.to_datetime(df_price['Date'])

#new_df = pd.merge(new_df, df_price, how='left', on='date')

# %%
df_price.tail(10)
# Out:
#         Date        High         Low  Upper bound  Lower bound       Close  \
# 577  4/22/19  269.679993  262.480011   337.099991   196.860008  262.750000
# 578  4/23/19  265.600006  255.750000   332.000007   191.812500  263.899994
# 579  4/24/19  265.320007  258.000000   331.650009   193.500000  258.660004
# 580  4/25/19  259.000000  246.070007   323.750000   184.552505  247.630005
# 581  4/26/19  246.679993  231.130005   308.349991   173.347504  235.139999
# 582  4/29/19  243.979996  232.169998   304.974995   174.127499  241.470001
# 583  4/30/19  244.210007  237.000000   305.262509   177.750000  238.690002
# 584   5/1/19  240.000000  231.500000   300.000000   173.625000  234.009995
# 585   5/2/19  247.130005  237.720001   308.912506   178.290001  244.100006
# 586   5/3/19  256.609985  243.490005   320.762481   182.617504  255.030000
#
#           date
# 577 2019-04-22
# 578 2019-04-23
# 579 2019-04-24
# 580 2019-04-25
# 581 2019-04-26
# 582 2019-04-29
# 583 2019-04-30
# 584 2019-05-01
# 585 2019-05-02
# 586 2019-05-03

# %%
new_df.head(10)
# Out:
#           date  negatives  positives     ratio  negatives (t-1)  \
# 315 2019-05-03         19         20  0.512821             26.0
# 314 2019-05-02         26         23  0.469388             32.0
# 313 2019-05-01         32         15  0.319149             15.0
# 312 2019-04-30         15         12  0.444444             22.0
# 311 2019-04-29         22         11  0.333333             65.0
# 310 2019-04-26         65         37  0.362745             87.0
# 309 2019-04-25         87         46  0.345865             59.0
# 308 2019-04-24         59         42  0.415842             16.0
# 307 2019-04-23         16         16  0.500000             22.0
# 306 2019-04-22         22         13  0.371429              5.0
#
#      positives (t-1)  ratio (t-1)  negatives (t-2)  positives (t-2)  \
# 315             23.0     0.469388             32.0             15.0
# 314             15.0     0.319149             15.0             12.0
# 313             12.0     0.444444             22.0             11.0
# 312             11.0     0.333333             65.0             37.0
# 311             37.0     0.362745             87.0             46.0
# 310             46.0     0.345865             59.0             42.0
# 309             42.0     0.415842             16.0             16.0
# 308             16.0     0.500000             22.0             13.0
# 307             13.0     0.371429              5.0             10.0
# 306             10.0     0.666667              3.0              4.0
#
#      ratio (t-2)     ...       ratio (t-4)  negatives (t-5)  positives (t-5)  \
# 315     0.319149     ...          0.333333             65.0             37.0
# 314     0.444444     ...          0.362745             87.0             46.0
# 313     0.333333     ...          0.345865             59.0             42.0
# 312     0.362745     ...          0.415842             16.0             16.0
# 311     0.345865     ...          0.500000             22.0             13.0
# 310     0.415842     ...          0.371429              5.0             10.0
# 309     0.500000     ...          0.666667              3.0              4.0
# 308     0.371429     ...          0.571429             11.0              9.0
# 307     0.666667     ...          0.450000             17.0              6.0
# 306     0.571429     ...          0.260870             12.0              9.0
#
#      ratio (t-5)  negatives (t-6)  positives (t-6)  ratio (t-6)  \
# 315     0.362745             87.0             46.0     0.345865
# 314     0.345865             59.0             42.0     0.415842
# 313     0.415842             16.0             16.0     0.500000
# 312     0.500000             22.0             13.0     0.371429
# 311     0.371429              5.0             10.0     0.666667
# 310     0.666667              3.0              4.0     0.571429
# 309     0.571429             11.0              9.0     0.450000
# 308     0.450000             17.0              6.0     0.260870
# 307     0.260870             12.0              9.0     0.428571
# 306     0.428571             18.0             19.0     0.513514
#
#      negatives (t-7)  positives (t-7)  ratio (t-7)
# 315             59.0             42.0     0.415842
# 314             16.0             16.0     0.500000
# 313             22.0             13.0     0.371429
# 312              5.0             10.0     0.666667
# 311              3.0              4.0     0.571429
# 310             11.0              9.0     0.450000
# 309             17.0              6.0     0.260870
# 308             12.0              9.0     0.428571
# 307             18.0             19.0     0.513514
# 306              7.0              9.0     0.562500
#
# [10 rows x 25 columns]

# %%
pd.merge(df_price, new_df, on='date', how='outer')

# %%
test.tail(10)
# Out:
#         Date        High         Low  Upper bound  Lower bound       Close  \
# 577  4/22/19  269.679993  262.480011   337.099991   196.860008  262.750000
# 578  4/23/19  265.600006  255.750000   332.000007   191.812500  263.899994
# 579  4/24/19  265.320007  258.000000   331.650009   193.500000  258.660004
# 580  4/25/19  259.000000  246.070007   323.750000   184.552505  247.630005
# 581  4/26/19  246.679993  231.130005   308.349991   173.347504  235.139999
# 582  4/29/19  243.979996  232.169998   304.974995   174.127499  241.470001
# 583  4/30/19  244.210007  237.000000   305.262509   177.750000  238.690002
# 584   5/1/19  240.000000  231.500000   300.000000   173.625000  234.009995
# 585   5/2/19  247.130005  237.720001   308.912506   178.290001  244.100006
# 586   5/3/19  256.609985  243.490005   320.762481   182.617504  255.030000
#
#           date  negatives  positives     ratio     ...       ratio (t-4)  \
# 577 2019-04-22       22.0       13.0  0.371429     ...          0.260870
# 578 2019-04-23       16.0       16.0  0.500000     ...          0.450000
# 579 2019-04-24       59.0       42.0  0.415842     ...          0.571429
# 580 2019-04-25       87.0       46.0  0.345865     ...          0.666667
# 581 2019-04-26       65.0       37.0  0.362745     ...          0.371429
# 582 2019-04-29       22.0       11.0  0.333333     ...          0.500000
# 583 2019-04-30       15.0       12.0  0.444444     ...          0.415842
# 584 2019-05-01       32.0       15.0  0.319149     ...          0.345865
# 585 2019-05-02       26.0       23.0  0.469388     ...          0.362745
# 586 2019-05-03       19.0       20.0  0.512821     ...          0.333333
#
#      negatives (t-5)  positives (t-5)  ratio (t-5)  negatives (t-6)  \
# 577             12.0              9.0     0.428571             18.0
# 578             17.0              6.0     0.260870             12.0
# 579             11.0              9.0     0.450000             17.0
# 580              3.0              4.0     0.571429             11.0
# 581              5.0             10.0     0.666667              3.0
# 582             22.0             13.0     0.371429              5.0
# 583             16.0             16.0     0.500000             22.0
# 584             59.0             42.0     0.415842             16.0
# 585             87.0             46.0     0.345865             59.0
# 586             65.0             37.0     0.362745             87.0
#
#      positives (t-6)  ratio (t-6)  negatives (t-7)  positives (t-7)  \
# 577             19.0     0.513514              7.0              9.0
# 578              9.0     0.428571             18.0             19.0
# 579              6.0     0.260870             12.0              9.0
# 580              9.0     0.450000             17.0              6.0
# 581              4.0     0.571429             11.0              9.0
# 582             10.0     0.666667              3.0              4.0
# 583             13.0     0.371429              5.0             10.0
# 584             16.0     0.500000             22.0             13.0
# 585             42.0     0.415842             16.0             16.0
# 586             46.0     0.345865             59.0             42.0
#
#      ratio (t-7)
# 577     0.562500
# 578     0.513514
# 579     0.428571
# 580     0.260870
# 581     0.450000
# 582     0.571429
# 583     0.666667
# 584     0.371429
# 585     0.500000
# 586     0.415842
#
# [10 rows x 31 columns]

# %%
new_df['label'] = new_df['Close'].shift() > new_df['Close']
new_df['label'] = new_df['label'].astype(int)

# %%
new_df.head(10)
# Out:
#         date   Date_x      High_x       Low_x  Upper bound_x  Lower bound_x  \
# 0 2017-01-03   1/3/17  220.330002  210.960007     275.412503     158.220005
# 1 2017-01-04   1/4/17  228.000000  214.309998     285.000000     160.732498
# 2 2017-01-05   1/5/17  227.479996  221.949997     284.349995     166.462498
# 3 2017-01-06   1/6/17  230.309998  225.449997     287.887497     169.087498
# 4 2017-01-09   1/9/17  231.919998  228.000000     289.899997     171.000000
# 5 2017-01-10  1/10/17  232.000000  226.889999     290.000000     170.167499
# 6 2017-01-11  1/11/17  229.979996  226.679993     287.474995     170.009995
# 7 2017-01-12  1/12/17  230.699997  225.580002     288.374996     169.185001
# 8 2017-01-13  1/13/17  237.850006  229.589996     297.312507     172.192497
# 9 2017-01-17  1/17/17  239.960007  234.369995     299.950009     175.777496
#
#       Close_x  negatives  positives  ratio     ...           Low_y  \
# 0  216.990005        NaN        NaN    NaN     ...      210.960007
# 1  226.990005        NaN        NaN    NaN     ...      214.309998
# 2  226.750000        NaN        NaN    NaN     ...      221.949997
# 3  229.009995        NaN        NaN    NaN     ...      225.449997
# 4  231.279999        NaN        NaN    NaN     ...      228.000000
# 5  229.869995        NaN        NaN    NaN     ...      226.889999
# 6  229.729996        NaN        NaN    NaN     ...      226.679993
# 7  229.589996        NaN        NaN    NaN     ...      225.580002
# 8  237.750000        NaN        NaN    NaN     ...      229.589996
# 9  235.580002        NaN        NaN    NaN     ...      234.369995
#
#    Upper bound_y  Lower bound_y     Close_y     Date        High         Low  \
# 0     275.412503     158.220005  216.990005   1/3/17  220.330002  210.960007
# 1     285.000000     160.732498  226.990005   1/4/17  228.000000  214.309998
# 2     284.349995     166.462498  226.750000   1/5/17  227.479996  221.949997
# 3     287.887497     169.087498  229.009995   1/6/17  230.309998  225.449997
# 4     289.899997     171.000000  231.279999   1/9/17  231.919998  228.000000
# 5     290.000000     170.167499  229.869995  1/10/17  232.000000  226.889999
# 6     287.474995     170.009995  229.729996  1/11/17  229.979996  226.679993
# 7     288.374996     169.185001  229.589996  1/12/17  230.699997  225.580002
# 8     297.312507     172.192497  237.750000  1/13/17  237.850006  229.589996
# 9     299.950009     175.777496  235.580002  1/17/17  239.960007  234.369995
#
#    Upper bound  Lower bound       Close
# 0   275.412503   158.220005  216.990005
# 1   285.000000   160.732498  226.990005
# 2   284.349995   166.462498  226.750000
# 3   287.887497   169.087498  229.009995
# 4   289.899997   171.000000  231.279999
# 5   290.000000   170.167499  229.869995
# 6   287.474995   170.009995  229.729996
# 7   288.374996   169.185001  229.589996
# 8   297.312507   172.192497  237.750000
# 9   299.950009   175.777496  235.580002
#
# [10 rows x 56 columns]

# %%
del new_df['Date']
#del new_df['Date_x']

# %%
new_df = new_df.drop(['High', 'Low', 'Upper bound', 'Lower bound', 'Close'], axis=1)

# %%
new_df.head()
# Out:
#         date  Date_x      High_x       Low_x  Upper bound_x  Lower bound_x  \
# 0 2017-01-03  1/3/17  220.330002  210.960007     275.412503     158.220005
# 1 2017-01-04  1/4/17  228.000000  214.309998     285.000000     160.732498
# 2 2017-01-05  1/5/17  227.479996  221.949997     284.349995     166.462498
# 3 2017-01-06  1/6/17  230.309998  225.449997     287.887497     169.087498
# 4 2017-01-09  1/9/17  231.919998  228.000000     289.899997     171.000000
#
#       Close_x  negatives  positives  ratio     ...           Low_y  \
# 0  216.990005        NaN        NaN    NaN     ...      210.960007
# 1  226.990005        NaN        NaN    NaN     ...      214.309998
# 2  226.750000        NaN        NaN    NaN     ...      221.949997
# 3  229.009995        NaN        NaN    NaN     ...      225.449997
# 4  231.279999        NaN        NaN    NaN     ...      228.000000
#
#    Upper bound_y  Lower bound_y     Close_y  Date_y      High_y       Low_y  \
# 0     275.412503     158.220005  216.990005  1/3/17  220.330002  210.960007
# 1     285.000000     160.732498  226.990005  1/4/17  228.000000  214.309998
# 2     284.349995     166.462498  226.750000  1/5/17  227.479996  221.949997
# 3     287.887497     169.087498  229.009995  1/6/17  230.309998  225.449997
# 4     289.899997     171.000000  231.279999  1/9/17  231.919998  228.000000
#
#    Upper bound_y  Lower bound_y     Close_y
# 0     275.412503     158.220005  216.990005
# 1     285.000000     160.732498  226.990005
# 2     284.349995     166.462498  226.750000
# 3     287.887497     169.087498  229.009995
# 4     289.899997     171.000000  231.279999
#
# [5 rows x 50 columns]

# %%
new_df.to_csv(output_dataset_name)
