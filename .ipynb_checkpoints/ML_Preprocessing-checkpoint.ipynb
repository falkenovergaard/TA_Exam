# %% [markdown]
# Load in our labeled data

# %%
import pandas as pd
from dateutil import parser

dataset = 'data/output/vader/vader_bitcoin.xlsx'
output_dataset_name = 'ML_Data/dm_ready.csv'
price_data = 'data/price/BTC.csv'

df = pd.read_excel(dataset)
df.columns = ['date', 'comment', 'label', 'compound_score']
df['date'] = pd.to_datetime(df['date'], dayfirst=True)

# %%
del df['comment']
del df['compound_score']

# %%
df.head()
# Out:
#         date  label
# 0 2019-05-04      0
# 1 2019-05-04      1
# 2 2019-05-04      0
# 3 2019-05-04      0
# 4 2019-05-04      1

# %% [markdown]
# Loop through all comments and create a new DataFrame that hosts the number of positives and negatives for each day.

# %%
rows = []
prices = []
grouped = df.groupby('date')
for date, group in grouped:
    positives = len(group[group['label'] == 1])
    negatives = len(group[group['label'] == 0])
        
    new_row = {
        'date': date,
        'positives': positives,
        'negatives': negatives,
        'ratio': positives / (positives + negatives)
    }
    
    rows.append(new_row)

# %%
new_df = pd.DataFrame(rows)

# %%
new_df.tail()
# Out:
#           date  negatives  positives     ratio
# 457 2019-04-30         18          8  0.307692
# 458 2019-05-01         18         11  0.379310
# 459 2019-05-02         39         21  0.350000
# 460 2019-05-03         43         20  0.317460
# 461 2019-05-04         21         11  0.343750

# %%
new_df = new_df.sort_values(['date'],ascending=[False])

# %%
new_df.head(5)
# Out:
#           date  negatives  positives     ratio
# 461 2019-05-04         21         11  0.343750
# 460 2019-05-03         43         20  0.317460
# 459 2019-05-02         39         21  0.350000
# 458 2019-05-01         18         11  0.379310
# 457 2019-04-30         18          8  0.307692

# %% [markdown]
# Loop through new DataFrame and add 2 lags to each day

# %%
lags = range(1, 3)

# %%
new_df = new_df.assign(**{
    '{} (t-{})'.format(col, t): new_df[col].shift(t)
    for t in lags
    for col in new_df
})

# %%
del new_df['date (t-1)']
del new_df['date (t-2)']

# %%
new_df.head(10)
# Out:
#           date  negatives  positives     ratio  negatives (t-1)  \
# 461 2019-05-04         21         11  0.343750              NaN
# 460 2019-05-03         43         20  0.317460             21.0
# 459 2019-05-02         39         21  0.350000             43.0
# 458 2019-05-01         18         11  0.379310             39.0
# 457 2019-04-30         18          8  0.307692             18.0
# 456 2019-04-29         15          7  0.318182             18.0
# 455 2019-04-28         30          9  0.230769             15.0
# 454 2019-04-27         25         17  0.404762             30.0
# 453 2019-04-26         32         23  0.418182             25.0
# 452 2019-04-25         29         27  0.482143             32.0
#
#      positives (t-1)  ratio (t-1)  negatives (t-2)  positives (t-2)  \
# 461              NaN          NaN              NaN              NaN
# 460             11.0     0.343750              NaN              NaN
# 459             20.0     0.317460             21.0             11.0
# 458             21.0     0.350000             43.0             20.0
# 457             11.0     0.379310             39.0             21.0
# 456              8.0     0.307692             18.0             11.0
# 455              7.0     0.318182             18.0              8.0
# 454              9.0     0.230769             15.0              7.0
# 453             17.0     0.404762             30.0              9.0
# 452             23.0     0.418182             25.0             17.0
#
#      ratio (t-2)
# 461          NaN
# 460          NaN
# 459     0.343750
# 458     0.317460
# 457     0.350000
# 456     0.379310
# 455     0.307692
# 454     0.318182
# 453     0.230769
# 452     0.404762

# %%
new_df.fillna(0, inplace=True)

# %%
df_price = pd.read_excel(price_data)
#df_price['date'] = pd.to_datetime(df_price['Date'])

#new_df = pd.merge(new_df, df_price, how='inner', on='date')

# %%
df_price.head()
# Out:
#                                                   Date;High;Low;Upper bound;Lower Bound;Close
# 12/31/16;965 469971;942  400024;1206 83746375;706                           800018;963.380005
# 1/1/17;1001  609985;956  099976;1252 01248125;717                           074982;995.440002
# 1/2/17;1031  680054;990  200012;1289 6000675;742                           650009;1017.049988
# 1/3/17;1035  469971;1006 530029;1294 33746375;754                        89752175;1033.300049
# 1/4/17;1148  540039;1022 320007;1435 67504875;766                        74000525;1135.410034

# %%
new_df['label'] = new_df['Close'].shift() > new_df['Close']
new_df['label'] = new_df['label'].astype(int)
# Out:
# -----------------------------------------------------------------------
# KeyError                              Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Close'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                              Traceback (most recent call last)
# <ipython-input-30-65f67b30dda1> in <module>()
# ----> 1 new_df['label'] = new_df['Close'].shift() > new_df['Close']
#       2 new_df['label'] = new_df['label'].astype(int)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Close'

# %%
new_df.head(10)
# Out:
#         date  negatives  positives     ratio  negatives (t-1)  \
# 0 2019-05-04         21         11  0.343750              0.0
# 1 2019-05-03         43         20  0.317460             21.0
# 2 2019-05-02         39         21  0.350000             43.0
# 3 2019-05-01         18         11  0.379310             39.0
# 4 2019-04-30         18          8  0.307692             18.0
# 5 2019-04-29         15          7  0.318182             18.0
# 6 2019-04-28         30          9  0.230769             15.0
# 7 2019-04-27         25         17  0.404762             30.0
# 8 2019-04-26         32         23  0.418182             25.0
# 9 2019-04-25         29         27  0.482143             32.0
#
#    positives (t-1)  ratio (t-1)  negatives (t-2)  positives (t-2)  \
# 0              0.0     0.000000              0.0              0.0
# 1             11.0     0.343750              0.0              0.0
# 2             20.0     0.317460             21.0             11.0
# 3             21.0     0.350000             43.0             20.0
# 4             11.0     0.379310             39.0             21.0
# 5              8.0     0.307692             18.0             11.0
# 6              7.0     0.318182             18.0              8.0
# 7              9.0     0.230769             15.0              7.0
# 8             17.0     0.404762             30.0              9.0
# 9             23.0     0.418182             25.0             17.0
#
#    ratio (t-2)  ...         Low_y  Upper Bound_y  Lower Bound_y    Date_y  \
# 0     0.000000  ...   4938.000000   10480.379882              0  05-04-19
# 1     0.000000  ...   3720.489990    7787.040040              0  05-03-19
# 2     0.343750  ...   3415.669922    6895.759766              0  05-02-19
# 3     0.317460  ...   3841.129883    7853.839844              0  05-01-19
# 4     0.350000  ...   5346.700195   10834.339844              0  30-04-19
# 5     0.379310  ...   5224.640137   10744.459960              0  29-04-19
# 6     0.307692  ...   5162.810059   10599.019532              0  28-04-19
# 7     0.318182  ...   5218.419922   10627.400390              0  27-04-19
# 8     0.230769  ...   5192.450195   10565.940430              0  26-04-19
# 9     0.404762  ...   5104.180176   10723.879882              0  25-04-19
#
#           High          Low   Upper Bound  Lower Bound      Date label
# 0  5240.189941  4938.000000  10480.379882            0  05-04-19     0
# 1  3893.520020  3720.489990   7787.040040            0  05-03-19     1
# 2  3447.879883  3415.669922   6895.759766            0  05-02-19     1
# 3  3926.919922  3841.129883   7853.839844            0  05-01-19     0
# 4  5417.169922  5346.700195  10834.339844            0  30-04-19     0
# 5  5372.229980  5224.640137  10744.459960            0  29-04-19     1
# 6  5299.509766  5162.810059  10599.019532            0  28-04-19     1
# 7  5313.700195  5218.419922  10627.400390            0  27-04-19     0
# 8  5282.970215  5192.450195  10565.940430            0  26-04-19     1
# 9  5361.939941  5104.180176  10723.879882            0  25-04-19     0
#
# [10 rows x 26 columns]

# %%
#del new_df['Date']
del new_df['Date_x']

# %%
new_df.head(10)
# Out:
#         date  negatives  positives     ratio  negatives (t-1)  \
# 0 2019-05-04         21         11  0.343750              0.0
# 1 2019-05-03         43         20  0.317460             21.0
# 2 2019-05-02         39         21  0.350000             43.0
# 3 2019-05-01         18         11  0.379310             39.0
# 4 2019-04-30         18          8  0.307692             18.0
# 5 2019-04-29         15          7  0.318182             18.0
# 6 2019-04-28         30          9  0.230769             15.0
# 7 2019-04-27         25         17  0.404762             30.0
# 8 2019-04-26         32         23  0.418182             25.0
# 9 2019-04-25         29         27  0.482143             32.0
#
#    positives (t-1)  ratio (t-1)  negatives (t-2)  positives (t-2)  \
# 0              0.0     0.000000              0.0              0.0
# 1             11.0     0.343750              0.0              0.0
# 2             20.0     0.317460             21.0             11.0
# 3             21.0     0.350000             43.0             20.0
# 4             11.0     0.379310             39.0             21.0
# 5              8.0     0.307692             18.0             11.0
# 6              7.0     0.318182             18.0              8.0
# 7              9.0     0.230769             15.0              7.0
# 8             17.0     0.404762             30.0              9.0
# 9             23.0     0.418182             25.0             17.0
#
#    ratio (t-2)  ...    Lower Bound_x       High_y        Low_y  Upper Bound_y  \
# 0     0.000000  ...                0  5240.189941  4938.000000   10480.379882
# 1     0.000000  ...                0  3893.520020  3720.489990    7787.040040
# 2     0.343750  ...                0  3447.879883  3415.669922    6895.759766
# 3     0.317460  ...                0  3926.919922  3841.129883    7853.839844
# 4     0.350000  ...                0  5417.169922  5346.700195   10834.339844
# 5     0.379310  ...                0  5372.229980  5224.640137   10744.459960
# 6     0.307692  ...                0  5299.509766  5162.810059   10599.019532
# 7     0.318182  ...                0  5313.700195  5218.419922   10627.400390
# 8     0.230769  ...                0  5282.970215  5192.450195   10565.940430
# 9     0.404762  ...                0  5361.939941  5104.180176   10723.879882
#
#    Lower Bound_y         High          Low   Upper Bound  Lower Bound  label
# 0              0  5240.189941  4938.000000  10480.379882            0      0
# 1              0  3893.520020  3720.489990   7787.040040            0      1
# 2              0  3447.879883  3415.669922   6895.759766            0      1
# 3              0  3926.919922  3841.129883   7853.839844            0      0
# 4              0  5417.169922  5346.700195  10834.339844            0      0
# 5              0  5372.229980  5224.640137  10744.459960            0      1
# 6              0  5299.509766  5162.810059  10599.019532            0      1
# 7              0  5313.700195  5218.419922  10627.400390            0      0
# 8              0  5282.970215  5192.450195  10565.940430            0      1
# 9              0  5361.939941  5104.180176  10723.879882            0      0
#
# [10 rows x 23 columns]

# %%
new_df.to_csv(output_dataset_name)
